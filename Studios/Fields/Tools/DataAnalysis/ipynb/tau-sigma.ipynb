# %%
from sympy import *
init_printing()

# %%
t = symbols('t')

# %%
tau = lambda t: (1/pi)*asin(abs(sin(pi*t)))
sigma = lambda t: sign(sin(2*pi*t))
f = t**2

# %%
#plot(tau(t), sigma(t), (t,-0.5,2.5))

# %%
ntau = Abs(t-1-floor(t-0.5))
dntau = Derivative(ntau, t)

# %%
p = plot(ntau, tau(t), (t,-0.5,3), xlim=(-3,3), ylim=(-1.2,1.2), show=false)
p[0].line_color = 'r'
p[1].line_color = 'b'
p.show()

# %%
sigma = lambda t: 1-2*floor(0.5-(floor(t)-t))
sigma(t)
# Out:
# -2⋅⌊t - ⌊t⌋ + 0.5⌋ + 1

# %%
plot(sigma(t), ntau, (t,-2,2))

# %%
plot(t-floor(t), (t, -1,1))

# %%
t=0.99
t-floor(t)
# Out:
# 0.990000000000000
