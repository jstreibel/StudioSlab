# %%
from sympy import *

init_printing(scale=1.75, forecolor='w')

# %%
z, t, x, ω, k = symbols('z t x ω k')
g = Function('g')(z)
h = Function('h')(z)
s = Function('s')(t,x)

# %%
def f(A: RealNumber, k : Integer):
    return A*sin(2*pi*k*x)

# %%
su =f(1,5)

plot(su, sign(su))
