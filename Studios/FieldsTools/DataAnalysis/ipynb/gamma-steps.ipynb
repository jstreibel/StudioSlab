# %%
from sympy import *
init_printing()

# %%
u = symbols('u')

# %%
gamma = 1/sqrt(1-u**2)
gamma
# Out:
#       1
# ─────────────
#    __________
#   ╱    2
# ╲╱  - u  + 1

# %%
plot(1/gamma, (u, -1, 1))
