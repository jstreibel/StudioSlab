# %%
from sympy import *
init_printing()

# %%
r, alpha, eps, sigma = symbols("r alpha epsilon sigma")

# %%
U = lambda r: eps/alpha * (1-r/sigma)**alpha * Heaviside(1-r/sigma)
U(r)
# Out:
#            α
#   ⎛  r    ⎞   ⎛  r    ⎞
# ε⋅⎜- ─ + 1⎟ ⋅θ⎜- ─ + 1⎟
#   ⎝  σ    ⎠   ⎝  σ    ⎠
# ───────────────────────
#            α

# %%
V = U(r).subs(((sigma, 1), (eps, 1), (alpha, 0.001)))
dV_out = -V.diff(r)
plot(V, (r,0,2))
plot(dV_out, (r,0,2))
