# %%
from sympy import *

init_printing(scale=1.75, forecolor='w')

# %%
ϕ, x, t, eps = symbols('\phi x t varepsilon')

# %%
plot(sqrt(x**2 + 10), sqrt(x**2 + 5), sqrt(x**2 + 2.5), sqrt(x**2 + 1.25), sqrt(x**2 + 0.6125), 0)

# %%
plot(10*log(cosh(0.1*x)), x, -x)

# %%
func = lambda a : a*log(cosh(x/a))
plot(func(9).diff(x), func(3).diff(x) , func(1).diff(x))

# %%
func(eps)
# Out:
#               ⎛    ⎛    x     ⎞⎞
# varepsilon⋅log⎜cosh⎜──────────⎟⎟
#               ⎝    ⎝varepsilon⎠⎠

# %%
func(eps).diff(x)
# Out:
#     ⎛    x     ⎞
# sinh⎜──────────⎟
#     ⎝varepsilon⎠
# ────────────────
#     ⎛    x     ⎞
# cosh⎜──────────⎟
#     ⎝varepsilon⎠

# %%
plot(func(1).diff(x), tanh(x/1.1))
